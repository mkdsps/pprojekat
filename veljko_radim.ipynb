# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
import clean.cleaning as cd

train_data = pd.read_parquet("./data/block1_train.parquet")
test_data  = pd.read_parquet("./data/block2_test.parquet")

#train_data = cd.clean_all(train_data)

# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
import clean.cleaning as cd
import feats.features as ft

train_data = pd.read_parquet("data/block1_train.parquet")
test_data  = pd.read_parquet("data/block2_test.parquet")

train_data = cd.clean_all(train_data)
train_data = ft.features_all(train_data)
test_data = ft.features_all(test_data)
# Out:
# ✅ Kreiran: vehicle_score
# ================================================================================
# UKLANJANJE VISOKO KORELISANIH FEATURE-A (prag: 0.97)
# ================================================================================
# Broj numeričkih kolona za proveru: 11
#
# ✅ Nema kolona za izbacivanje (sve korelacije ispod praga)
# ================================================================================
# UKLANJANJE VISOKO KORELISANIH FEATURE-A (prag: 0.97)
# ================================================================================
# Broj numeričkih kolona za proveru: 11
#
# ✅ Nema kolona za izbacivanje (sve korelacije ispod praga)

# %%
target_cols = [f"Insurer_{chr(i)}_price" for i in range(ord('A'), ord('K') + 1)]
deductible_cols = [f"Insurer_{chr(i)}_deductible" for i in range(ord('A'), ord('K') + 1)]

# %%
import pandas as pd
import numpy as np

def detect_categorical_columns(df):
    categorical_cols = []
    
    for col in df.columns:
        # Uzimamo samo vrednosti koje nisu NaN za testiranje
        non_null_values = df[col].dropna()
        
        if non_null_values.empty:
            # Ako je cela kolona prazna, tretiramo je kao kategorijsku ili je brišemo
            categorical_cols.append(col)
            continue
            
        try:
            # Pokušavamo da konvertujemo celu kolonu (bez NaN) u float
            pd.to_numeric(non_null_values, errors='raise')
        except (ValueError, TypeError):
            # Ako baci grešku, znači da ima teksta koji nije broj
            categorical_cols.append(col)
            
    return categorical_cols

# Korišćenje:
cat_cols = detect_categorical_columns(train_data)
print(cat_cols)
# Out:
# ['vehicle_number_plate', 'coverage', 'payment_frequency', 'contractor_birthdate', 'is_driver_owner', 'usage', 'second_driver_birthdate', 'second_driver_claim_free_years', 'vehicle_maker', 'vehicle_model', 'vehicle_fuel_type', 'vehicle_primary_color', 'vehicle_first_registration_date', 'vehicle_country_first_registration_date', 'vehicle_last_registration_date', 'vehicle_inspection_report_date', 'vehicle_inspection_expiry_date', 'vehicle_odometer_verdict_code', 'vehicle_is_imported', 'vehicle_is_imported_within_last_12_months', 'vehicle_can_be_registered', 'vehicle_has_open_recall', 'vehicle_is_marked_for_export', 'vehicle_is_taxi', 'province', 'municipality', 'postal_code_houses_owned_by_rental_association_ratio']

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

def encode_categorical(train, test, cat_cols, high_sparsity_threshold=10):

    train_enc = train.copy()
    test_enc = test.copy()
    
    high_sparse_cols = [c for c in cat_cols if train[c].nunique() > high_sparsity_threshold]
    low_sparse_cols = [c for c in cat_cols if train[c].nunique() <= high_sparsity_threshold]
    
    # Ordinal encoding za high sparsity
    if high_sparse_cols:
        oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
        train_enc[high_sparse_cols] = oe.fit_transform(train[high_sparse_cols])
        test_enc[high_sparse_cols] = oe.transform(test[high_sparse_cols])
    
    # One-hot encoding za low sparsity
    if low_sparse_cols:
        ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
        train_ohe = ohe.fit_transform(train[low_sparse_cols])
        test_ohe = ohe.transform(test[low_sparse_cols])
        
        # Napravimo kolone sa imenima
        ohe_cols = ohe.get_feature_names_out(low_sparse_cols)
        train_ohe_df = pd.DataFrame(train_ohe, columns=ohe_cols, index=train.index)
        test_ohe_df = pd.DataFrame(test_ohe, columns=ohe_cols, index=test.index)
        
        # Drop original low sparsity cols i dodaj one-hot
        train_enc = train_enc.drop(columns=low_sparse_cols).join(train_ohe_df)
        test_enc = test_enc.drop(columns=low_sparse_cols).join(test_ohe_df)
    
    return train_enc, test_enc

# %%
train_data_enc, test_data_enc = encode_categorical(train_data, test_data, cat_cols)

# %%
object_cols = train_data_enc.select_dtypes(include=['object']).columns
# Out:
# C:\Users\velja\AppData\Local\Temp\ipykernel_29672\4049719601.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   object_cols = train_data_enc.select_dtypes(include=['object']).columns

# %%
# 1. Uzimamo sve kolone koje su trenutno tipa 'object'
object_cols = train_data_enc.select_dtypes(include=['object']).columns

print(f"Započinjem konverziju {len(object_cols)} kolona...")

for col in object_cols:
    # Konvertujemo u numerik (float64 po defaultu)
    # errors='coerce' sprečava pucanje koda ako naiđe na tekstualni bag
    train_data_enc[col] = pd.to_numeric(train_data_enc[col], errors='coerce')

    # Isto radimo i za test set da bi struktura ostala identična
    if col in test_data_enc.columns:
        test_data_enc[col] = pd.to_numeric(test_data_enc[col], errors='coerce')

# 2. Finalna provera tipova
print("-" * 30)
print("Konverzija gotova!")
print(f"Preostalo 'object' kolona u train: {len(train_data_enc.select_dtypes(include=['object']).columns)}")
# Out:
# C:\Users\velja\AppData\Local\Temp\ipykernel_29672\1673138626.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   object_cols = train_data_enc.select_dtypes(include=['object']).columns
# Započinjem konverziju 105 kolona...
# ------------------------------
# Konverzija gotova!
# Preostalo 'object' kolona u train: 0

# %%
# from catboost import CatBoostRegressor
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_absolute_error, r2_score
# import pandas as pd
# import numpy as np

# # 1. Podela podataka
# X = train_data_enc.drop(columns=target_cols, errors='ignore').copy()
# Y = train_data[target_cols]

# X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

# trained_models = {}

# print("Počinjem trening po targetima sa CatBoost-om...")

# for col in target_cols:
#     print(f"--- Treniram CatBoost model za: {col} ---")
    
#     # Filtriranje validnih redova (tamo gde target nije NaN)
#     valid_mask = Y_train[col].notna()
#     X_train_sub = X_train[valid_mask]
#     y_train_sub = Y_train.loc[valid_mask, col]
    
#     # 2. CatBoost Model
#     # 'allow_writing_files=False' sprečava CatBoost da pravi foldere sa logovima u svakom krugu petlje
#     model = CatBoostRegressor(
#         iterations=1000,
#         learning_rate=0.05,
#         depth=6,
#         loss_function='MAE', # Možeš ostaviti 'RMSE', ali MAE je često stabilniji za osiguranje
#         random_seed=42,
#         verbose=100,         # Ispisuje napredak na svakih 100 stabala
#         allow_writing_files=False,
#         thread_count=-1      # Koristi sve CPU jezgre (ekvivalent za n_jobs=-1)
#     )
    
#     # Treniranje
#     model.fit(X_train_sub, y_train_sub)
#     trained_models[col] = model
    
#     # 3. Dodavanje predviđanja kao feature-a za naredne iteracije
#     # .predict() u CatBoost-u radi identično kao u XGBoost-u
#     X_train[f"pred_{col}"] = model.predict(X_train)
#     X_val[f"pred_{col}"] = model.predict(X_val)
    
#     print(f"Model za {col} je završen i dodat kao feature.")

# print("\nSvi CatBoost modeli su istrenirani!")

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
import pandas as pd
import numpy as np

# 1. Definisanje targeta
target_cols = [f"Insurer_{chr(i)}_price" for i in range(ord('A'), ord('K') + 1)]
available_targets = [t for t in target_cols if t in train_data_enc.columns]

# Split podataka
X = train_data_enc.drop(columns=target_cols, errors='ignore').copy()
Y = train_data_enc[target_cols]
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

# Trajna konverzija kategoričkih kolona u string (rešava CatBoostError: nan/float)
all_cat_cols = list(set(cat_cols).intersection(X_train.columns))
for c in all_cat_cols:
    X_train[c] = X_train[c].fillna("Missing").astype(str)
    X_val[c] = X_val[c].fillna("Missing").astype(str)

trained_models = {}

print("🚀 Počinjem dinamički trening na LOGARITMU targeta...")

for col in available_targets:
    print(f"\n" + "="*50)
    print(f"🎯 TARGET: {col} (Log-Transform)")
    
    train_mask = Y_train[col].notna()
    val_mask = Y_val[col].notna()
    
    X_t_sub = X_train[train_mask].copy()
    # TRANSFORMACIJA: Uzimamo log(1 + y) da izbegnemo log(0) ako negde postoji
    y_t_sub_log = np.log1p(Y_train.loc[train_mask, col])
    
    X_v_sub = X_val[val_mask].copy()
    y_v_sub_original = Y_val.loc[val_mask, col] # Ovo čuvamo za pravi MAE
    y_v_sub_log = np.log1p(y_v_sub_original)

    current_cat_features = [c for c in all_cat_cols if c in X_t_sub.columns]

    # 1. SELEKCIJA (na logaritmu)
    selector = CatBoostRegressor(iterations=250, learning_rate=0.1, depth=6, verbose=0, allow_writing_files=False, random_seed=42)
    selector.fit(X_t_sub, y_t_sub_log, cat_features=current_cat_features)
    
    fi = selector.get_feature_importance()
    fn = np.array(selector.feature_names_)
    sorted_idx = np.argsort(fi)[::-1]
    cumulative_importance = np.cumsum(fi[sorted_idx])
    
    final_num = max(5, min(np.where(cumulative_importance >= 95.0)[0][0] + 1, 50))
    dynamic_features = fn[sorted_idx][:final_num].tolist()

    # 2. FINALNI TRENING
    final_cat = [c for c in current_cat_features if c in dynamic_features]
    
    final_model = CatBoostRegressor(
        iterations=1500, 
        learning_rate=0.05, 
        depth=6, 
        loss_function='RMSE', # Kod log transformacije, RMSE na log-skali često radi bolje
        verbose=100, 
        allow_writing_files=False
    )

    final_model.fit(
        X_t_sub[dynamic_features], y_t_sub_log,
        eval_set=(X_v_sub[dynamic_features], y_v_sub_log),
        cat_features=final_cat,
        early_stopping_rounds=50
    )
    
    trained_models[col] = final_model
    
    # 3. PREDVIĐANJE I REVERZIJA (Back to Normal)
    # Predviđamo logaritamske vrednosti
    train_preds_log = final_model.predict(X_train[dynamic_features])
    val_preds_log = final_model.predict(X_val[dynamic_features])
    
    # Vraćamo u normalne vrednosti: exp(x) - 1
    train_preds_original = np.expm1(train_preds_log)
    val_preds_original = np.expm1(val_preds_log)
    
    # 4. IZRAČUNAVANJE NORMALNOG MAE ZA ISPIS
    # Računamo MAE samo na validacionom podskupu gde target nije bio NaN
    current_mae = mean_absolute_error(y_v_sub_original, val_preds_original[val_mask])
    
    # Sačuvaj normalizovana predviđanja za Chaining
    X_train[f"pred_{col}"] = train_preds_original
    X_val[f"pred_{col}"] = val_preds_original
    
    print(f"\n📊 Rezultat za {col}:")
    print(f"   Realni MAE: {current_mae:.4f}")
    print(f"✅ Završen {col}")

print("\n🏁 Svi log-modeli su istrenirani!")
# Out:
# 🚀 Počinjem dinamički trening na LOGARITMU targeta...
#
# ==================================================
# 🎯 TARGET: Insurer_A_price (Log-Transform)
# 0:	learn: 0.6480539	test: 0.6507217	best: 0.6507217 (0)	total: 191ms	remaining: 4m 46s
# 100:	learn: 0.1902660	test: 0.1778428	best: 0.1778428 (100)	total: 15s	remaining: 3m 27s
# 200:	learn: 0.1706761	test: 0.1599906	best: 0.1599906 (200)	total: 32.9s	remaining: 3m 32s
# 300:	learn: 0.1630051	test: 0.1532310	best: 0.1532310 (300)	total: 49.6s	remaining: 3m 17s
# 400:	learn: 0.1571186	test: 0.1479113	best: 0.1479113 (400)	total: 1m 5s	remaining: 2m 58s
# 500:	learn: 0.1534156	test: 0.1445753	best: 0.1445753 (500)	total: 1m 20s	remaining: 2m 39s
# 600:	learn: 0.1504996	test: 0.1418723	best: 0.1418723 (600)	total: 1m 35s	remaining: 2m 23s
# 700:	learn: 0.1481085	test: 0.1397092	best: 0.1397092 (700)	total: 1m 51s	remaining: 2m 7s
# 800:	learn: 0.1461199	test: 0.1379099	best: 0.1379099 (800)	total: 2m 7s	remaining: 1m 51s
# 900:	learn: 0.1442005	test: 0.1362184	best: 0.1362184 (900)	total: 2m 23s	remaining: 1m 35s
# 1000:	learn: 0.1427640	test: 0.1349198	best: 0.1349198 (1000)	total: 2m 39s	remaining: 1m 19s
# 1100:	learn: 0.1414292	test: 0.1337366	best: 0.1337366 (1100)	total: 2m 55s	remaining: 1m 3s
# 1200:	learn: 0.1401883	test: 0.1326234	best: 0.1326234 (1200)	total: 3m 12s	remaining: 47.8s
# 1300:	learn: 0.1391298	test: 0.1317008	best: 0.1317008 (1300)	total: 3m 30s	remaining: 32.2s
# 1400:	learn: 0.1381276	test: 0.1308588	best: 0.1308588 (1400)	total: 3m 48s	remaining: 16.2s
# 1499:	learn: 0.1371782	test: 0.1300326	best: 0.1300326 (1499)	total: 4m 4s	remaining: 0us
#
# bestTest = 0.1300325664
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_A_price:
#    Realni MAE: 10.5642
# ✅ Završen Insurer_A_price
#
# ==================================================
# 🎯 TARGET: Insurer_B_price (Log-Transform)
# 0:	learn: 0.5934821	test: 0.5950971	best: 0.5950971 (0)	total: 163ms	remaining: 4m 4s
# 100:	learn: 0.1547686	test: 0.1542961	best: 0.1542961 (100)	total: 15.8s	remaining: 3m 38s
# 200:	learn: 0.1415279	test: 0.1411235	best: 0.1411235 (200)	total: 31.1s	remaining: 3m 20s
# 300:	learn: 0.1358896	test: 0.1355177	best: 0.1355177 (300)	total: 46.4s	remaining: 3m 4s
# 400:	learn: 0.1321059	test: 0.1314385	best: 0.1314385 (400)	total: 1m 2s	remaining: 2m 50s
# 500:	learn: 0.1296987	test: 0.1290455	best: 0.1290455 (500)	total: 1m 18s	remaining: 2m 35s
# 600:	learn: 0.1277714	test: 0.1270903	best: 0.1270903 (600)	total: 1m 34s	remaining: 2m 21s
# 700:	learn: 0.1260741	test: 0.1253927	best: 0.1253927 (700)	total: 1m 49s	remaining: 2m 5s
# 800:	learn: 0.1247897	test: 0.1241435	best: 0.1241435 (800)	total: 2m 6s	remaining: 1m 50s
# 900:	learn: 0.1236723	test: 0.1231240	best: 0.1231240 (900)	total: 2m 22s	remaining: 1m 34s
# 1000:	learn: 0.1226972	test: 0.1221905	best: 0.1221905 (1000)	total: 2m 38s	remaining: 1m 18s
# 1100:	learn: 0.1217527	test: 0.1212983	best: 0.1212983 (1100)	total: 2m 54s	remaining: 1m 3s
# 1200:	learn: 0.1209360	test: 0.1205269	best: 0.1205269 (1200)	total: 3m 10s	remaining: 47.4s
# 1300:	learn: 0.1201898	test: 0.1198298	best: 0.1198298 (1300)	total: 3m 26s	remaining: 31.5s
# 1400:	learn: 0.1194752	test: 0.1192116	best: 0.1192116 (1400)	total: 3m 42s	remaining: 15.7s
# 1499:	learn: 0.1188051	test: 0.1186038	best: 0.1186038 (1499)	total: 3m 58s	remaining: 0us
#
# bestTest = 0.1186037987
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_B_price:
#    Realni MAE: 10.1805
# ✅ Završen Insurer_B_price
#
# ==================================================
# 🎯 TARGET: Insurer_C_price (Log-Transform)
# 0:	learn: 0.5580235	test: 0.5580650	best: 0.5580650 (0)	total: 168ms	remaining: 4m 11s
# 100:	learn: 0.1504440	test: 0.1493269	best: 0.1493269 (100)	total: 15s	remaining: 3m 27s
# 200:	learn: 0.1392472	test: 0.1383663	best: 0.1383663 (200)	total: 30.4s	remaining: 3m 16s
# 300:	learn: 0.1339945	test: 0.1333268	best: 0.1333268 (300)	total: 45.5s	remaining: 3m 1s
# 400:	learn: 0.1302181	test: 0.1297264	best: 0.1297264 (400)	total: 1m	remaining: 2m 46s
# 500:	learn: 0.1273704	test: 0.1269519	best: 0.1269519 (500)	total: 1m 16s	remaining: 2m 31s
# 600:	learn: 0.1250139	test: 0.1245701	best: 0.1245701 (600)	total: 1m 31s	remaining: 2m 17s
# 700:	learn: 0.1232462	test: 0.1229437	best: 0.1229437 (700)	total: 1m 47s	remaining: 2m 2s
# 800:	learn: 0.1216630	test: 0.1213757	best: 0.1213757 (800)	total: 2m 3s	remaining: 1m 48s
# 900:	learn: 0.1203804	test: 0.1201285	best: 0.1201285 (900)	total: 2m 19s	remaining: 1m 33s
# 1000:	learn: 0.1192886	test: 0.1191510	best: 0.1191510 (1000)	total: 2m 36s	remaining: 1m 17s
# 1100:	learn: 0.1183386	test: 0.1183004	best: 0.1183004 (1100)	total: 2m 51s	remaining: 1m 2s
# 1200:	learn: 0.1174544	test: 0.1175060	best: 0.1175060 (1200)	total: 3m 7s	remaining: 46.7s
# 1300:	learn: 0.1166370	test: 0.1167520	best: 0.1167520 (1300)	total: 3m 24s	remaining: 31.2s
# 1400:	learn: 0.1158738	test: 0.1160613	best: 0.1160613 (1400)	total: 3m 40s	remaining: 15.6s
# 1499:	learn: 0.1151561	test: 0.1154120	best: 0.1154120 (1499)	total: 3m 55s	remaining: 0us
#
# bestTest = 0.1154120307
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_C_price:
#    Realni MAE: 8.5372
# ✅ Završen Insurer_C_price
#
# ==================================================
# 🎯 TARGET: Insurer_D_price (Log-Transform)
# 0:	learn: 0.5884344	test: 0.5902383	best: 0.5902383 (0)	total: 171ms	remaining: 4m 16s
# 100:	learn: 0.1618032	test: 0.1619607	best: 0.1619607 (100)	total: 14.4s	remaining: 3m 19s
# 200:	learn: 0.1508110	test: 0.1509581	best: 0.1509581 (200)	total: 28.1s	remaining: 3m 1s
# 300:	learn: 0.1455290	test: 0.1454232	best: 0.1454232 (300)	total: 43.3s	remaining: 2m 52s
# 400:	learn: 0.1420086	test: 0.1418495	best: 0.1418495 (400)	total: 57.9s	remaining: 2m 38s
# 500:	learn: 0.1393684	test: 0.1392004	best: 0.1392004 (500)	total: 1m 12s	remaining: 2m 24s
# 600:	learn: 0.1372125	test: 0.1370391	best: 0.1370391 (600)	total: 1m 26s	remaining: 2m 10s
# 700:	learn: 0.1354754	test: 0.1353500	best: 0.1353500 (700)	total: 1m 41s	remaining: 1m 56s
# 800:	learn: 0.1340268	test: 0.1339720	best: 0.1339720 (800)	total: 1m 56s	remaining: 1m 41s
# 900:	learn: 0.1327403	test: 0.1327675	best: 0.1327675 (900)	total: 2m 11s	remaining: 1m 27s
# 1000:	learn: 0.1315859	test: 0.1316965	best: 0.1316965 (1000)	total: 2m 25s	remaining: 1m 12s
# 1100:	learn: 0.1305821	test: 0.1307598	best: 0.1307598 (1100)	total: 2m 40s	remaining: 58.2s
# 1200:	learn: 0.1296436	test: 0.1299142	best: 0.1299142 (1200)	total: 2m 55s	remaining: 43.6s
# 1300:	learn: 0.1288463	test: 0.1292236	best: 0.1292236 (1300)	total: 3m 9s	remaining: 29.1s
# 1400:	learn: 0.1280095	test: 0.1284116	best: 0.1284116 (1400)	total: 3m 24s	remaining: 14.5s
# 1499:	learn: 0.1272788	test: 0.1277869	best: 0.1277869 (1499)	total: 3m 39s	remaining: 0us
#
# bestTest = 0.1277869279
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_D_price:
#    Realni MAE: 10.3052
# ✅ Završen Insurer_D_price
#
# ==================================================
# 🎯 TARGET: Insurer_E_price (Log-Transform)
# 0:	learn: 0.5760462	test: 0.5781336	best: 0.5781336 (0)	total: 160ms	remaining: 4m
# 100:	learn: 0.2328773	test: 0.2314036	best: 0.2314036 (100)	total: 15s	remaining: 3m 28s
# 200:	learn: 0.2179975	test: 0.2166758	best: 0.2166758 (200)	total: 30.1s	remaining: 3m 14s
# 300:	learn: 0.2096367	test: 0.2079844	best: 0.2079844 (300)	total: 45.1s	remaining: 2m 59s
# 400:	learn: 0.2038098	test: 0.2019942	best: 0.2019942 (400)	total: 1m	remaining: 2m 46s
# 500:	learn: 0.1998114	test: 0.1980749	best: 0.1980749 (500)	total: 1m 15s	remaining: 2m 30s
# 600:	learn: 0.1966055	test: 0.1948340	best: 0.1948340 (600)	total: 1m 30s	remaining: 2m 16s
# 700:	learn: 0.1940401	test: 0.1924202	best: 0.1924202 (700)	total: 1m 46s	remaining: 2m
# 800:	learn: 0.1918369	test: 0.1903322	best: 0.1903322 (800)	total: 2m 1s	remaining: 1m 46s
# 900:	learn: 0.1897696	test: 0.1884311	best: 0.1884311 (900)	total: 2m 17s	remaining: 1m 31s
# 1000:	learn: 0.1879677	test: 0.1868267	best: 0.1868267 (1000)	total: 2m 32s	remaining: 1m 15s
# 1100:	learn: 0.1862888	test: 0.1853627	best: 0.1853627 (1100)	total: 2m 47s	remaining: 1m
# 1200:	learn: 0.1849065	test: 0.1841839	best: 0.1841839 (1200)	total: 3m 2s	remaining: 45.5s
# 1300:	learn: 0.1835676	test: 0.1830911	best: 0.1830911 (1300)	total: 3m 17s	remaining: 30.2s
# 1400:	learn: 0.1823052	test: 0.1820561	best: 0.1820561 (1400)	total: 3m 32s	remaining: 15s
# 1499:	learn: 0.1811658	test: 0.1811351	best: 0.1811351 (1499)	total: 3m 46s	remaining: 0us
#
# bestTest = 0.1811351387
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_E_price:
#    Realni MAE: 17.6794
# ✅ Završen Insurer_E_price
#
# ==================================================
# 🎯 TARGET: Insurer_F_price (Log-Transform)
# 0:	learn: 0.5731642	test: 0.5750862	best: 0.5750862 (0)	total: 135ms	remaining: 3m 22s
# 100:	learn: 0.1604286	test: 0.1615377	best: 0.1615377 (100)	total: 12.5s	remaining: 2m 53s
# 200:	learn: 0.1511125	test: 0.1521525	best: 0.1521525 (200)	total: 24.2s	remaining: 2m 36s
# 300:	learn: 0.1466345	test: 0.1473956	best: 0.1473956 (300)	total: 35.9s	remaining: 2m 23s
# 400:	learn: 0.1441309	test: 0.1448879	best: 0.1448879 (400)	total: 50.6s	remaining: 2m 18s
# 500:	learn: 0.1423128	test: 0.1430085	best: 0.1430085 (500)	total: 1m 3s	remaining: 2m 6s
# 600:	learn: 0.1410067	test: 0.1418102	best: 0.1418102 (600)	total: 1m 18s	remaining: 1m 56s
# 700:	learn: 0.1398936	test: 0.1408374	best: 0.1408373 (699)	total: 1m 30s	remaining: 1m 43s
# 800:	learn: 0.1389256	test: 0.1400148	best: 0.1400148 (800)	total: 1m 42s	remaining: 1m 29s
# 900:	learn: 0.1380765	test: 0.1393430	best: 0.1393430 (900)	total: 1m 54s	remaining: 1m 15s
# 1000:	learn: 0.1372809	test: 0.1386649	best: 0.1386649 (1000)	total: 2m 5s	remaining: 1m 2s
# 1100:	learn: 0.1365571	test: 0.1380945	best: 0.1380945 (1100)	total: 2m 17s	remaining: 49.7s
# 1200:	learn: 0.1359111	test: 0.1375700	best: 0.1375700 (1200)	total: 2m 29s	remaining: 37.1s
# 1300:	learn: 0.1353503	test: 0.1371640	best: 0.1371640 (1300)	total: 2m 40s	remaining: 24.6s
# 1400:	learn: 0.1347829	test: 0.1367520	best: 0.1367520 (1400)	total: 2m 52s	remaining: 12.2s
# 1499:	learn: 0.1342454	test: 0.1363555	best: 0.1363555 (1499)	total: 3m 3s	remaining: 0us
#
# bestTest = 0.1363555313
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_F_price:
#    Realni MAE: 10.9636
# ✅ Završen Insurer_F_price
#
# ==================================================
# 🎯 TARGET: Insurer_G_price (Log-Transform)
# 0:	learn: 0.5249281	test: 0.5269709	best: 0.5269709 (0)	total: 127ms	remaining: 3m 10s
# 100:	learn: 0.1339674	test: 0.1363328	best: 0.1363328 (100)	total: 11.1s	remaining: 2m 34s
# 200:	learn: 0.1206066	test: 0.1229713	best: 0.1229713 (200)	total: 21.3s	remaining: 2m 17s
# 300:	learn: 0.1152708	test: 0.1173996	best: 0.1173996 (300)	total: 31.7s	remaining: 2m 6s
# 400:	learn: 0.1120768	test: 0.1141042	best: 0.1141042 (400)	total: 42.1s	remaining: 1m 55s
# 500:	learn: 0.1099695	test: 0.1120015	best: 0.1120015 (500)	total: 52.7s	remaining: 1m 45s
# 600:	learn: 0.1084226	test: 0.1105288	best: 0.1105288 (600)	total: 1m 3s	remaining: 1m 34s
# 700:	learn: 0.1071483	test: 0.1093477	best: 0.1093477 (700)	total: 1m 13s	remaining: 1m 23s
# 800:	learn: 0.1060274	test: 0.1083398	best: 0.1083398 (800)	total: 1m 23s	remaining: 1m 13s
# 900:	learn: 0.1051075	test: 0.1075074	best: 0.1075074 (900)	total: 1m 34s	remaining: 1m 2s
# 1000:	learn: 0.1042673	test: 0.1067793	best: 0.1067793 (1000)	total: 1m 44s	remaining: 52.3s
# 1100:	learn: 0.1035138	test: 0.1061166	best: 0.1061166 (1100)	total: 1m 55s	remaining: 41.9s
# 1200:	learn: 0.1027916	test: 0.1055134	best: 0.1055134 (1200)	total: 2m 5s	remaining: 31.3s
# 1300:	learn: 0.1021031	test: 0.1049376	best: 0.1049376 (1300)	total: 2m 16s	remaining: 20.9s
# 1400:	learn: 0.1014888	test: 0.1044378	best: 0.1044378 (1400)	total: 2m 26s	remaining: 10.4s
# 1499:	learn: 0.1009209	test: 0.1039982	best: 0.1039982 (1499)	total: 2m 37s	remaining: 0us
#
# bestTest = 0.1039981954
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_G_price:
#    Realni MAE: 6.8958
# ✅ Završen Insurer_G_price
#
# ==================================================
# 🎯 TARGET: Insurer_H_price (Log-Transform)
# 0:	learn: 0.5601525	test: 0.5626194	best: 0.5626194 (0)	total: 66.3ms	remaining: 1m 39s
# 100:	learn: 0.2100957	test: 0.2061029	best: 0.2061029 (100)	total: 7.49s	remaining: 1m 43s
# 200:	learn: 0.1882120	test: 0.1844716	best: 0.1844716 (200)	total: 14.1s	remaining: 1m 31s
# 300:	learn: 0.1760403	test: 0.1725232	best: 0.1725232 (300)	total: 20.2s	remaining: 1m 20s
# 400:	learn: 0.1681086	test: 0.1648237	best: 0.1648237 (400)	total: 26.2s	remaining: 1m 11s
# 500:	learn: 0.1623769	test: 0.1595107	best: 0.1595107 (500)	total: 32.2s	remaining: 1m 4s
# 600:	learn: 0.1578185	test: 0.1554940	best: 0.1554940 (600)	total: 38.2s	remaining: 57.2s
# 700:	learn: 0.1541066	test: 0.1521304	best: 0.1521304 (700)	total: 44.2s	remaining: 50.4s
# 800:	learn: 0.1512516	test: 0.1497914	best: 0.1497914 (800)	total: 50.1s	remaining: 43.7s
# 900:	learn: 0.1485739	test: 0.1475457	best: 0.1475457 (900)	total: 56.1s	remaining: 37.3s
# 1000:	learn: 0.1464115	test: 0.1459122	best: 0.1459122 (1000)	total: 1m 2s	remaining: 30.9s
# 1100:	learn: 0.1442580	test: 0.1442431	best: 0.1442431 (1100)	total: 1m 8s	remaining: 24.7s
# 1200:	learn: 0.1421229	test: 0.1426609	best: 0.1426609 (1200)	total: 1m 14s	remaining: 18.5s
# 1300:	learn: 0.1404384	test: 0.1413963	best: 0.1413963 (1300)	total: 1m 20s	remaining: 12.3s
# 1400:	learn: 0.1387571	test: 0.1402016	best: 0.1402016 (1400)	total: 1m 26s	remaining: 6.08s
# 1499:	learn: 0.1372102	test: 0.1391167	best: 0.1391167 (1499)	total: 1m 32s	remaining: 0us
#
# bestTest = 0.1391167388
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_H_price:
#    Realni MAE: 12.4647
# ✅ Završen Insurer_H_price
#
# ==================================================
# 🎯 TARGET: Insurer_I_price (Log-Transform)
# 0:	learn: 0.5828290	test: 0.5823195	best: 0.5823195 (0)	total: 117ms	remaining: 2m 55s
# 100:	learn: 0.2352287	test: 0.2289821	best: 0.2289821 (100)	total: 9.35s	remaining: 2m 9s
# 200:	learn: 0.2237533	test: 0.2175226	best: 0.2175226 (200)	total: 18.7s	remaining: 2m
# 300:	learn: 0.2181459	test: 0.2117069	best: 0.2117069 (300)	total: 27.8s	remaining: 1m 50s
# 400:	learn: 0.2141697	test: 0.2075922	best: 0.2075922 (400)	total: 37s	remaining: 1m 41s
# 500:	learn: 0.2107375	test: 0.2041510	best: 0.2041510 (500)	total: 46.3s	remaining: 1m 32s
# 600:	learn: 0.2081379	test: 0.2016767	best: 0.2016767 (600)	total: 55.6s	remaining: 1m 23s
# 700:	learn: 0.2059135	test: 0.1997387	best: 0.1997387 (700)	total: 1m 5s	remaining: 1m 14s
# 800:	learn: 0.2039059	test: 0.1979133	best: 0.1979133 (800)	total: 1m 15s	remaining: 1m 5s
# 900:	learn: 0.2022496	test: 0.1964834	best: 0.1964834 (900)	total: 1m 24s	remaining: 56.4s
# 1000:	learn: 0.2006913	test: 0.1951768	best: 0.1951768 (1000)	total: 1m 34s	remaining: 47s
# 1100:	learn: 0.1992337	test: 0.1939523	best: 0.1939523 (1100)	total: 1m 43s	remaining: 37.7s
# 1200:	learn: 0.1978851	test: 0.1929175	best: 0.1929175 (1200)	total: 1m 53s	remaining: 28.2s
# 1300:	learn: 0.1967164	test: 0.1919677	best: 0.1919677 (1300)	total: 2m 3s	remaining: 18.8s
# 1400:	learn: 0.1956867	test: 0.1912016	best: 0.1912016 (1400)	total: 2m 12s	remaining: 9.39s
# 1499:	learn: 0.1946414	test: 0.1903864	best: 0.1903864 (1499)	total: 2m 22s	remaining: 0us
#
# bestTest = 0.1903864339
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_I_price:
#    Realni MAE: 14.5229
# ✅ Završen Insurer_I_price
#
# ==================================================
# 🎯 TARGET: Insurer_J_price (Log-Transform)
# 0:	learn: 0.5569028	test: 0.5564647	best: 0.5564647 (0)	total: 103ms	remaining: 2m 33s
# 100:	learn: 0.1700827	test: 0.1657384	best: 0.1657384 (100)	total: 10.8s	remaining: 2m 29s
# 200:	learn: 0.1561787	test: 0.1520180	best: 0.1520180 (200)	total: 21s	remaining: 2m 15s
# 300:	learn: 0.1484454	test: 0.1441601	best: 0.1441601 (300)	total: 31.7s	remaining: 2m 6s
# 400:	learn: 0.1438741	test: 0.1397004	best: 0.1397004 (400)	total: 41.9s	remaining: 1m 54s
# 500:	learn: 0.1406060	test: 0.1366319	best: 0.1366319 (500)	total: 51.1s	remaining: 1m 41s
# 600:	learn: 0.1380347	test: 0.1343799	best: 0.1343799 (600)	total: 59.4s	remaining: 1m 28s
# 700:	learn: 0.1358845	test: 0.1324156	best: 0.1324156 (700)	total: 1m 7s	remaining: 1m 17s
# 800:	learn: 0.1339810	test: 0.1307447	best: 0.1307447 (800)	total: 1m 16s	remaining: 1m 6s
# 900:	learn: 0.1323431	test: 0.1293050	best: 0.1293050 (900)	total: 1m 27s	remaining: 58s
# 1000:	learn: 0.1308821	test: 0.1280303	best: 0.1280303 (1000)	total: 1m 39s	remaining: 49.4s
# 1100:	learn: 0.1295548	test: 0.1269329	best: 0.1269329 (1100)	total: 1m 48s	remaining: 39.4s
# 1200:	learn: 0.1283461	test: 0.1259368	best: 0.1259368 (1200)	total: 1m 57s	remaining: 29.3s
# 1300:	learn: 0.1272965	test: 0.1251193	best: 0.1251193 (1300)	total: 2m 7s	remaining: 19.5s
# 1400:	learn: 0.1262932	test: 0.1243462	best: 0.1243462 (1400)	total: 2m 18s	remaining: 9.76s
# 1499:	learn: 0.1253996	test: 0.1236715	best: 0.1236715 (1499)	total: 2m 26s	remaining: 0us
#
# bestTest = 0.1236715126
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_J_price:
#    Realni MAE: 9.9779
# ✅ Završen Insurer_J_price
#
# ==================================================
# 🎯 TARGET: Insurer_K_price (Log-Transform)
# 0:	learn: 0.5808847	test: 0.5830714	best: 0.5830714 (0)	total: 129ms	remaining: 3m 13s
# 100:	learn: 0.1677642	test: 0.1686298	best: 0.1686298 (100)	total: 12.3s	remaining: 2m 50s
# 200:	learn: 0.1543953	test: 0.1553167	best: 0.1553167 (200)	total: 23.9s	remaining: 2m 34s
# 300:	learn: 0.1475300	test: 0.1483009	best: 0.1483009 (300)	total: 36s	remaining: 2m 23s
# 400:	learn: 0.1436676	test: 0.1446003	best: 0.1446003 (400)	total: 48s	remaining: 2m 11s
# 500:	learn: 0.1407229	test: 0.1417420	best: 0.1417420 (500)	total: 1m	remaining: 1m 59s
# 600:	learn: 0.1384191	test: 0.1396519	best: 0.1396519 (600)	total: 1m 12s	remaining: 1m 47s
# 700:	learn: 0.1366313	test: 0.1379921	best: 0.1379921 (700)	total: 1m 24s	remaining: 1m 36s
# 800:	learn: 0.1350662	test: 0.1366140	best: 0.1366140 (800)	total: 1m 36s	remaining: 1m 24s
# 900:	learn: 0.1337346	test: 0.1354257	best: 0.1354257 (900)	total: 1m 48s	remaining: 1m 12s
# 1000:	learn: 0.1324559	test: 0.1343183	best: 0.1343183 (1000)	total: 2m	remaining: 59.9s
# 1100:	learn: 0.1313260	test: 0.1333567	best: 0.1333567 (1100)	total: 2m 11s	remaining: 47.8s
# 1200:	learn: 0.1303617	test: 0.1325125	best: 0.1325125 (1200)	total: 2m 23s	remaining: 35.8s
# 1300:	learn: 0.1294694	test: 0.1317824	best: 0.1317824 (1300)	total: 2m 35s	remaining: 23.7s
# 1400:	learn: 0.1286275	test: 0.1311103	best: 0.1311103 (1400)	total: 2m 46s	remaining: 11.8s
# 1499:	learn: 0.1278302	test: 0.1304716	best: 0.1304716 (1499)	total: 2m 58s	remaining: 0us
#
# bestTest = 0.1304716363
# bestIteration = 1499
#
#
# 📊 Rezultat za Insurer_K_price:
#    Realni MAE: 12.9312
# ✅ Završen Insurer_K_price
#
# 🏁 Svi log-modeli su istrenirani!

# %%
importance_data = []

for target_name, model in trained_models.items():
    # Izvlačenje važnosti i imena feature-a direktno iz modela
    fi = model.get_feature_importance()
    fn = model.feature_names_
    
    # Kreiranje privremenog DataFrame-a za ovaj model
    temp_df = pd.DataFrame({
        'Target': target_name,
        'Feature': fn,
        'Importance': fi
    })
    
    # Sortiramo da najbitniji budu na vrhu za taj target
    temp_df = temp_df.sort_values(by='Importance', ascending=False)
    
    importance_data.append(temp_df)

# Spajamo sve u jedan veliki DataFrame
df_importance_final = pd.concat(importance_data, ignore_index=True)

# Eksport u CSV
df_importance_final.to_csv('model_feature_importances.csv', index=False)

print("✅ CSV sa važnošću feature-a je sačuvan pod imenom 'model_feature_importances.csv'")

# Prikaz top 5 za svaki target u konzoli radi provere
print(df_importance_final.groupby('Target').head(5))
# Out:
# ✅ CSV sa važnošću feature-a je sačuvan pod imenom 'model_feature_importances.csv'
#               Target                   Feature  Importance
# 0    Insurer_A_price          claim_free_years   23.992065
# 1    Insurer_A_price  payment_frequency_yearly   13.485071
# 2    Insurer_A_price      contractor_birthdate   13.404741
# 3    Insurer_A_price      Insurer_C_deductible    6.960302
# 4    Insurer_A_price         vehicle_value_new    4.240915
# 27   Insurer_B_price      pred_Insurer_A_price   66.784500
# 28   Insurer_B_price          claim_free_years    7.429620
# 29   Insurer_B_price            coverage_casco    4.276855
# 30   Insurer_B_price               vehicle_age    2.577644
# 31   Insurer_B_price              municipality    2.127496
# 54   Insurer_C_price      pred_Insurer_A_price   49.859703
# 55   Insurer_C_price      pred_Insurer_B_price   20.721521
# 56   Insurer_C_price             vehicle_maker    3.779486
# 57   Insurer_C_price      contractor_birthdate    3.546199
# 58   Insurer_C_price              municipality    3.089126
# 79   Insurer_D_price      pred_Insurer_B_price   28.179863
# 80   Insurer_D_price      pred_Insurer_A_price   21.289889
# 81   Insurer_D_price      pred_Insurer_C_price   16.739805
# 82   Insurer_D_price          claim_free_years    4.567724
# 83   Insurer_D_price      contractor_birthdate    3.683259
# 109  Insurer_E_price      pred_Insurer_C_price   19.311915
# 110  Insurer_E_price      pred_Insurer_A_price   17.641949
# 111  Insurer_E_price      pred_Insurer_B_price   12.673088
# 112  Insurer_E_price      pred_Insurer_D_price    5.134058
# 113  Insurer_E_price      vehicle_number_plate    3.604377
# 148  Insurer_F_price      pred_Insurer_D_price   19.017106
# 149  Insurer_F_price      pred_Insurer_A_price   18.742996
# 150  Insurer_F_price      pred_Insurer_C_price   16.108985
# 151  Insurer_F_price      pred_Insurer_B_price   11.516055
# 152  Insurer_F_price      pred_Insurer_E_price    7.244045
# 173  Insurer_G_price      pred_Insurer_B_price   52.190955
# 174  Insurer_G_price      pred_Insurer_F_price    5.739407
# 175  Insurer_G_price               vehicle_age    5.410096
# 176  Insurer_G_price          claim_free_years    5.366154
# 177  Insurer_G_price             coverage_mtpl    4.368884
# 199  Insurer_H_price          claim_free_years   12.784591
# 200  Insurer_H_price      pred_Insurer_G_price   10.027406
# 201  Insurer_H_price      pred_Insurer_C_price    9.025492
# 202  Insurer_H_price             coverage_mtpl    8.386927
# 203  Insurer_H_price      Insurer_B_deductible    7.873953
# 227  Insurer_I_price      pred_Insurer_D_price   30.780495
# 228  Insurer_I_price      Insurer_F_deductible    9.726531
# 229  Insurer_I_price      Insurer_D_deductible    8.693066
# 230  Insurer_I_price             coverage_mtpl    6.561382
# 231  Insurer_I_price      pred_Insurer_C_price    5.499166
# 254  Insurer_J_price      pred_Insurer_D_price   31.202021
# 255  Insurer_J_price      pred_Insurer_B_price    9.226618
# 256  Insurer_J_price         vehicle_value_new    8.697513
# 257  Insurer_J_price      contractor_birthdate    6.740245
# 258  Insurer_J_price          claim_free_years    5.282320
# 285  Insurer_K_price      pred_Insurer_D_price   21.606148
# 286  Insurer_K_price      pred_Insurer_B_price   18.898575
# 287  Insurer_K_price          claim_free_years    8.600037
# 288  Insurer_K_price      pred_Insurer_J_price    6.395258
# 289  Insurer_K_price      Insurer_K_deductible    5.306139

# %%
# import matplotlib.pyplot as plt
# target_to_plot = target_cols[-1] # Primer za poslednji target
# current_model = trained_models[target_to_plot]

# # CatBoost čuva imena feature-a na kojima je treniran!
# # Ovo je NAJSIGURNIJI način da izbegneš IndexError
# feature_names = current_model.feature_names_
# importances = current_model.get_feature_importance()

# # Sortiranje
# sorted_indices = np.argsort(importances)

# # Plotovanje
# plt.figure(figsize=(10, 20)) # Povećaj visinu jer imaš 100+ kolona
# plt.barh(np.array(feature_names)[sorted_indices], importances[sorted_indices])
# plt.xlabel('CatBoost Feature Importance')
# plt.title(f'Važnost kolona za target: {target_to_plot}')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 3
#       1 import matplotlib.pyplot as plt
#       2 target_to_plot = target_cols[-1] # Primer za poslednji target
# ----> 3 current_model = trained_models[target_to_plot]
#       4
#       5 # CatBoost čuva imena feature-a na kojima je treniran!
#       6 # Ovo je NAJSIGURNIJI način da izbegneš IndexError
#
# KeyError: 'Insurer_K_price'

# %%
feature_names = np.array(final_model.feature_names_)
importances = final_model.get_feature_importance()

# Sortiramo indekse od najmanjeg ka najvećem i uzimamo poslednjih 20
top_20_indices = np.argsort(importances)[-20:]
top_20_features = feature_names[top_20_indices].tolist()

print("Top 20 kolona za novi trening:")
print(top_20_features)

X_train_top = X_train[top_20_features]
X_val_top = X_val[top_20_features]
# Out:
# Top 20 kolona za novi trening:
# ['postal_code_average_property_value', 'vehicle_ownership_duration', 'postal_code_owner_occupied_houses_ratio', 'Insurer_J_deductible', 'Insurer_D_deductible', 'Insurer_I_deductible', 'postal_code_urban_category', 'vehicle_age', 'vehicle_power', 'coverage_casco', 'vehicle_model', 'vehicle_net_weight', 'vehicle_fuel_type_petrol', 'municipality', 'vehicle_value_new', 'Insurer_C_deductible', 'contractor_birthdate', 'claim_free_years', 'payment_frequency_yearly', 'payment_frequency_monthly']

# %%
model_top = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.05,
    depth=6,
    loss_function='MAE',
    random_seed=42,
    verbose=100,
    allow_writing_files=False
)

# Ako i dalje imaš kategoričke kolone među tih top 20, 
# moraš ih ponovo navesti (samo one koje su ostale u top 20)
new_cat_features = [col for col in cat_cols if col in top_20_features]

model_top.fit(
    X_train_top, Y_train[col], # Koristiš target iz petlje ili specifičan
    eval_set=(X_val_top, Y_val[col]),
    cat_features=new_cat_features
)
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[32], line 15
#      11 # Ako i dalje imaš kategoričke kolone među tih top 20,
#      12 # moraš ih ponovo navesti (samo one koje su ostale u top 20)
#      13 new_cat_features = [col for col in cat_cols if col in top_20_features]
#      14
# ---> 15 model_top.fit(
#      16     X_train_top, Y_train[col], # Koristiš target iz petlje ili specifičan
#      17     eval_set=(X_val_top, Y_val[col]),
#      18     cat_features=new_cat_features
#
# File c:\Users\velja\OneDrive\Desktop\Hackathon\pprojekat\venv\Lib\site-packages\catboost\core.py:6178, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, graph, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    6176 if 'loss_function' in params:
#    6177     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 6178 return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#    6179                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    6180                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    6181                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File c:\Users\velja\OneDrive\Desktop\Hackathon\pprojekat\venv\Lib\site-packages\catboost\core.py:2716, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2713 allow_clear_pool = train_params["allow_clear_pool"]
#    2715 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(params)]):
# -> 2716     self._train(
#    2717         train_pool,
#    2718         train_params["eval_sets"],
#    2719         params,
#    2720         allow_clear_pool,
#    2721         train_params["init_model"]
#    2722     )
#    2724 # Have property feature_importance possibly set
#    2725 loss = self._object._get_loss_function_name()
#
# File c:\Users\velja\OneDrive\Desktop\Hackathon\pprojekat\venv\Lib\site-packages\catboost\core.py:1824, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1823 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1824     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1825     self._set_trained_model_attributes()
#
# File _catboost.pyx:5430, in _catboost._CatBoost._train()
# -> 5430 'Could not get source, probably due dynamically evaluated source code.'
#
# File _catboost.pyx:5479, in _catboost._CatBoost._train()
# -> 5479 'Could not get source, probably due dynamically evaluated source code.'
#
# CatBoostError: catboost/libs/metrics/metric.cpp:7032: metric/loss-function MAE does not allow nan values in target data

# %%
from sklearn.metrics import r2_score
results = []

print("\n--- EVALUACIJA MODELA PO OSIGURAVAČIMA ---")

for col in target_cols:
    # 1. Provera da li predviđanje uopšte postoji u X_val
    pred_col_name = f"pred_{col}"
    if pred_col_name not in X_val.columns:
        print(f"Preskačem {col} - predviđanje nije pronađeno.")
        continue
    
    # 2. Uzimanje predviđenih i stvarnih vrednosti
    y_pred = X_val[pred_col_name]
    y_true = Y_val[col]
    
    # 3. FILTRIRANJE: Ovo je ključno jer CatBoost nije treniran na NaN vrednostima targeta
    # Moramo evaluirati samo tamo gde smo imali šta da uporedimo (gde stvarna cena postoji)
    mask = y_true.notna()
    
    if mask.sum() > 0:
        actuals = y_true[mask]
        predictions = y_pred[mask]
        
        mae = mean_absolute_error(actuals, predictions)
        r2 = r2_score(actuals, predictions)
        
        # Opciono: Dodajemo i Mean Price da vidimo koliki je MAE u odnosu na prosečnu cenu
        mean_val = actuals.mean()
        error_pct = (mae / mean_val) * 100 if mean_val != 0 else 0
        
        results.append({
            'Osiguravač': col.replace('Insurer_', '').replace('_price', ''),
            'MAE': round(mae, 2),
            'R2': round(r2, 4),
            'Error %': round(error_pct, 2)
        })

# 4. Prikaz rezultata u tabeli
df_results = pd.DataFrame(results)

# Sortiramo po MAE (od najboljeg ka najgorem modelu)
df_results = df_results.sort_values(by='MAE')

print(df_results.to_string(index=False))

print("-" * 40)
print(f"Prosečan MAE svih osiguravača: {df_results['MAE'].mean():.2f}")
print(f"Prosečan R2 score: {df_results['R2'].mean():.4f}")
# Out:
# --- EVALUACIJA MODELA PO OSIGURAVAČIMA ---
# Osiguravač   MAE     R2  Error %
#          G  6.90 0.9535     8.15
#          C  8.54 0.9418     9.57
#          J  9.98 0.9394     9.53
#          B 10.18 0.9372    10.18
#          D 10.31 0.9383    10.44
#          A 10.56 0.9548    10.85
#          F 10.96 0.9131    11.21
#          H 12.46 0.9060    10.74
#          K 12.93 0.9319    10.39
#          I 14.52 0.8635    15.32
#          E 17.68 0.8394    15.24
# ----------------------------------------
# Prosečan MAE svih osiguravača: 11.37
# Prosečan R2 score: 0.9199

# %%
print(f"\n📍 Najbitnijih 10 faktora za {col}:")
# Uzimamo top 10 radi preglednosti u konzoli, a sortiramo ih od najbitnijeg
# get_feature_importance() daje skorove, pa ih uparujemo sa imenima
top_scores = fi[np.argsort(fi)[-10:]][::-1]
top_names = fn[np.argsort(fi)[-10:]][::-1]

for name, score in zip(top_names, top_scores):
    print(f"  - {name}: {score:.2f}")
# Out:
# 📍 Najbitnijih 10 faktora za Insurer_K_price:
#   - pred_Insurer_D_price: 17.97
#   - pred_Insurer_B_price: 16.82
#   - pred_Insurer_E_price: 8.73
#   - claim_free_years: 8.63
#   - pred_Insurer_C_price: 5.68
#   - Insurer_K_deductible: 4.28
#   - vehicle_fuel_type_diesel: 4.21
#   - pred_Insurer_F_price: 4.06
#   - pred_Insurer_I_price: 4.02
#   - pred_Insurer_J_price: 2.63

# %%
import pandas as pd
from xgboost import XGBRegressor

# 1. PRIPREMA: Izbacujemo sve targete iz trening seta pre početka
# Moramo izbaciti 'Insurer_A_price', 'Insurer_B_price'... iz X setova
X_train_current = train_data_enc.drop(columns=target_cols, errors='ignore').copy()
X_test_current = test_data_enc.drop(columns=target_cols, errors='ignore').copy()

trained_models = {}
test_predictions = {}

print("Započeto treniranje...")

for col in target_cols:
    print(f"Obrađujem: {col}")
    
    # Maska za validne redove ostaje ista jer gledamo Y_train (originalne targete)
    valid_mask = Y_train[col].notna()
    
    # Uzimamo trenutne feature (oni sada NE sadrže originalne cene, samo predikcije)
    X_sub = X_train_current.loc[valid_mask]
    y_sub = Y_train.loc[valid_mask, col]
    
    model = XGBRegressor(
        n_estimators=1000,
        learning_rate=0.05,
        max_depth=6,
        tree_method='hist',
        random_state=42,
        n_jobs=-1
    )
    
    # Fit modela na čistim podacima
    model.fit(X_sub, y_sub)
    trained_models[col] = model
    
    # DODAVANJE PREDVIĐANJA KAO FEATURE:
    # Ovo je jedini način na koji sledeći model "vidi" cene prethodnih
    train_preds = model.predict(X_train_current)
    X_train_current[f"pred_{col}"] = train_preds
    
    test_preds = model.predict(X_test_current)
    X_test_current[f"pred_{col}"] = test_preds
    
    test_predictions[col] = np.round(test_preds, 2)

submission = pd.DataFrame(test_predictions)

submission.insert(0, 'quote_id', test_data['quote_id'].astype(int).values)

submission.to_csv('finalni_rezultati.csv', index=False, sep=';')

print("\n--- PROCES ZAVRŠEN ---")
print("Prvih par redova tvog submission-a:")
print(submission.head())
# Out:
# Započeto treniranje...
# Obrađujem: Insurer_A_price
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[14], line 21
#      17     # Maska za validne redove ostaje ista jer gledamo Y_train (originalne targete)
#      18     valid_mask = Y_train[col].notna()
#      19
#      20     # Uzimamo trenutne feature (oni sada NE sadrže originalne cene, samo predikcije)
# ---> 21     X_sub = X_train_current.loc[valid_mask]
#      22     y_sub = Y_train.loc[valid_mask, col]
#      23
#      24     model = XGBRegressor(
#
# File c:\Users\velja\OneDrive\Desktop\Hackathon\pprojekat\venv\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\velja\OneDrive\Desktop\Hackathon\pprojekat\venv\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429     return self._get_slice_axis(key, axis=axis)
#    1430 elif com.is_bool_indexer(key):
# -> 1431     return self._getbool_axis(key, axis=axis)
#    1432 elif is_list_like_indexer(key):
#    1433     # an iterable multi-selection
#    1434     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File c:\Users\velja\OneDrive\Desktop\Hackathon\pprojekat\venv\Lib\site-packages\pandas\core\indexing.py:1225, in _LocationIndexer._getbool_axis(self, key, axis)
#    1221 @final
#    1222 def _getbool_axis(self, key, axis: AxisInt):
#    1223     # caller is responsible for ensuring non-None axis
#    1224     labels = self.obj._get_axis(axis)
# -> 1225     key = check_bool_indexer(labels, key)
#    1226     inds = key.nonzero()[0]
#    1227     return self.obj.take(inds, axis=axis)
#
# File c:\Users\velja\OneDrive\Desktop\Hackathon\pprojekat\venv\Lib\site-packages\pandas\core\indexing.py:2677, in check_bool_indexer(index, key)
#    2675 indexer = result.index.get_indexer_for(index)
#    2676 if -1 in indexer:
# -> 2677     raise IndexingError(
#    2678         "Unalignable boolean Series provided as "
#    2679         "indexer (index of the boolean Series and of "
#    2680         "the indexed object do not match)."
#    2681     )
#    2683 result = result.take(indexer)
#    2685 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
test_data.shape
# Out:
# (164092, 144)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
import pandas as pd
import numpy as np

# 1. Priprema podataka
# Izbacujemo targete (cene) iz X seta pre podele, jer njih model ne sme da vidi kao ulaz
X = train_data_enc.drop(columns=target_cols, errors='ignore').copy()
Y = train_data[target_cols]

# Podela na Train i Val
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

trained_models = {}

print("Počinjem trening po targetima (sa chaining metodom)...")

for col in target_cols:
    print(f"--- Treniram model za: {col} ---")
    
    # Koristimo samo redove gde trenutni target u Y_train nije NaN
    valid_mask = Y_train[col].notna()
    
    # Uzimamo trenutne feature (originalni + predviđanja prethodnih modela)
    X_train_sub = X_train.loc[valid_mask]
    y_train_sub = Y_train.loc[valid_mask, col]
    
    # 2. Model definicija
    model = XGBRegressor(
        n_estimators=1000,
        learning_rate=0.05,
        max_depth=6,
        tree_method='hist',
        random_state=42,
        n_jobs=-1
    )
    
    # Trening
    model.fit(X_train_sub, y_train_sub)
    trained_models[col] = model
    
    # 3. DODAVANJE PREDVIĐANJA KAO NOVI FEATURE
    # Predviđamo za CEO X_train i X_val kako bi sledeći model imao ove podatke
    X_train[f"pred_{col}"] = model.predict(X_train)
    X_val[f"pred_{col}"] = model.predict(X_val)
    
    print(f"Model za {col} završen. Dodat feature 'pred_{col}' u Train i Val.")

print("\nSvi modeli su istrenirani! Sada možeš proveriti metrike.")

# --- OPCIONA PROVERA REZULTATA ---
results = []
for col in target_cols:
    y_true = Y_val[col]
    y_pred = X_val[f"pred_{col}"]
    mask = y_true.notna()
    
    mae = mean_absolute_error(y_true[mask], y_pred[mask])
    results.append({'Target': col, 'MAE': mae})

print("\nMAE po osiguravačima na validacionom setu:")
print(pd.DataFrame(results))
# Out:
# Počinjem trening po targetima (sa chaining metodom)...
# --- Treniram model za: Insurer_A_price ---
# Model za Insurer_A_price završen. Dodat feature 'pred_Insurer_A_price' u Train i Val.
# --- Treniram model za: Insurer_B_price ---
# Model za Insurer_B_price završen. Dodat feature 'pred_Insurer_B_price' u Train i Val.
# --- Treniram model za: Insurer_C_price ---
# Model za Insurer_C_price završen. Dodat feature 'pred_Insurer_C_price' u Train i Val.
# --- Treniram model za: Insurer_D_price ---
# Model za Insurer_D_price završen. Dodat feature 'pred_Insurer_D_price' u Train i Val.
# --- Treniram model za: Insurer_E_price ---
# Model za Insurer_E_price završen. Dodat feature 'pred_Insurer_E_price' u Train i Val.
# --- Treniram model za: Insurer_F_price ---
# Model za Insurer_F_price završen. Dodat feature 'pred_Insurer_F_price' u Train i Val.
# --- Treniram model za: Insurer_G_price ---
# Model za Insurer_G_price završen. Dodat feature 'pred_Insurer_G_price' u Train i Val.
# --- Treniram model za: Insurer_H_price ---
# Model za Insurer_H_price završen. Dodat feature 'pred_Insurer_H_price' u Train i Val.
# --- Treniram model za: Insurer_I_price ---
# Model za Insurer_I_price završen. Dodat feature 'pred_Insurer_I_price' u Train i Val.
# --- Treniram model za: Insurer_J_price ---
# Model za Insurer_J_price završen. Dodat feature 'pred_Insurer_J_price' u Train i Val.
# --- Treniram model za: Insurer_K_price ---
# Model za Insurer_K_price završen. Dodat feature 'pred_Insurer_K_price' u Train i Val.
#
# Svi modeli su istrenirani! Sada možeš proveriti metrike.
#
# MAE po osiguravačima na validacionom setu:
#              Target        MAE
# 0   Insurer_A_price  12.445129
# 1   Insurer_B_price  11.612943
# 2   Insurer_C_price  10.796713
# 3   Insurer_D_price  12.269809
# 4   Insurer_E_price  18.605483
# 5   Insurer_F_price  11.956905
# 6   Insurer_G_price   7.447456
# 7   Insurer_H_price  15.039967
# 8   Insurer_I_price  16.337037
# 9   Insurer_J_price  13.882767
# 10  Insurer_K_price  13.787913

# %%
print(pd.DataFrame(results))
# Out:
#              Target        MAE
# 0   Insurer_A_price  12.445129
# 1   Insurer_B_price  11.612943
# 2   Insurer_C_price  10.796713
# 3   Insurer_D_price  12.269809
# 4   Insurer_E_price  18.605483
# 5   Insurer_F_price  11.956905
# 6   Insurer_G_price   7.447456
# 7   Insurer_H_price  15.039967
# 8   Insurer_I_price  16.337037
# 9   Insurer_J_price  13.882767
# 10  Insurer_K_price  13.787913
